# %%
import tensorflow_addons as tfa

# Define the Lookahead Adam optimizer
def build_optimizer():
    adam = Adam(learning_rate=0.0001)
    lookahead = tfa.optimizers.Lookahead(adam)
    return lookahead

# Example of compiling model with Lookahead Adam optimizer
model = build_model()
model.compile(optimizer=build_optimizer(), loss='binary_crossentropy', metrics=['accuracy'])
