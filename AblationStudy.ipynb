# %%
# Define a simple model for comparison (without spatial attention)
def build_simple_model(input_shape=(256, 256, 3)):
    inputs = Input(shape=input_shape)
    x = VGG16(weights='imagenet', include_top=False, input_shape=input_shape)(inputs)
    x = GlobalAveragePooling2D()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    output = Dense(1, activation='sigmoid')(x)
    model = Model(inputs=inputs, outputs=output)
    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Train the model without attention
simple_model = build_simple_model()
simple_model.fit(train_generator, epochs=50, validation_data=val_generator)

# Now compare performance between the original model (with attention) and the simple model (without attention)
